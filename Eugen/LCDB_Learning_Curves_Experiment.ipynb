# %% [markdown]
# # Modular Experimental System: Learning Curve Extrapolation

# %% [markdown]
# ## Section 0: Configuration Dictionary (`CFG`)

# %%
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from scipy.stats import norm
from joblib import Parallel, delayed
import warnings
from pprint import pprint
import datetime

warnings.filterwarnings('ignore')

CFG = {
    'experiment_name': 'baseline_ridge_scaled_v1',
    'data': {
        'train_path': 'data/LCDB11_ER_train.hdf5',
        'eval_path': 'data/LCDB11_ER_eval.hdf5',
        'val_split': 0.1,  
        'random_seed': 42
    },
    'features': {
        'use_params': True,
        'use_stats': False,
        'use_log_anchors': False,
        'use_ohe_learners': False
    },
    'preprocessing': {
        'nan_handling': 'forward'
    },
    'fitting': {
        'method': 'pow2', # 'pow2', 'pow3', 'exp3', 'mmf4', 'wbl4'
        'n_inits': 5,
        'n_jobs': 4
    },
    'model': {
        # options: 'ridge', 'rf', 'hgb' (HistGradientBoosting)
        'type': 'ridge', 
    },
    'tuning': {
        # 'none', 'grid' (GridSearchCV), 'halving' (HalvingGridSearchCV)
        'method': 'grid', 
        'cv_folds': 3,
        'n_jobs': 4
    },
    'uncertainty': {
        'method': 'gaussian', # 'gaussian', 'kde', 'conformal', 'quantile'
    },
    'submission': {
        'demo_path': 'data/demo_submission.csv',
        'out_dir': 'submissions'
    }
}

np.random.seed(CFG['data']['random_seed'])
pprint(CFG)
# Out:
# {'data': {'eval_path': 'data/LCDB11_ER_eval.hdf5',
#           'random_seed': 42,
#           'train_path': 'data/LCDB11_ER_train.hdf5',
#           'val_split': 0.1},
#  'experiment_name': 'baseline_ridge_scaled_v1',
#  'features': {'use_log_anchors': False,
#               'use_ohe_learners': False,
#               'use_params': True,
#               'use_stats': False},
#  'fitting': {'method': 'pow2', 'n_inits': 5, 'n_jobs': 4},
#  'model': {'type': 'ridge'},
#  'preprocessing': {'nan_handling': 'forward'},
#  'submission': {'demo_path': 'data/demo_submission.csv',
#                 'out_dir': 'submissions'},
#  'tuning': {'cv_folds': 3, 'method': 'grid', 'n_jobs': 4},
#  'uncertainty': {'method': 'gaussian'}}

# %% [markdown]
# ## Section 1: Data Ingestion & Inspection

# %%
max_k = 136 
anchor_list = [int(np.ceil(16 * (2 ** (k / 8)))) for k in range(max_k + 1)]
x_anchors_all = np.array(anchor_list)

def load_hdf5_data(path):
    out = {}
    with h5py.File(path, 'r') as f:
        for key in f.keys():
            data = f[key][()]
            if data.dtype.kind == 'S':  
                data = [s.decode('utf-8') for s in data]
            out[key] = np.array(data)
    return out

train_data = load_hdf5_data(CFG['data']['train_path'])
eval_data = load_hdf5_data(CFG['data']['eval_path'])
train_full = train_data['error rate']
eval_full = eval_data['error rate']

def extract_train_curves(y_full):
    y_obs_list, y_tgt_list, m_list, valid_idx = [], [], [], []
    for i in range(y_full.shape[0]):
        curve = y_full[i]
        non_nans = np.where(~np.isnan(curve))[0]
        if len(non_nans) == 0: continue
        L = non_nans[-1] + 1
        if L > 16:
            M = L - 16
            y_obs_list.append(curve[:M])
            y_tgt_list.append(curve[L-1])
            m_list.append(M)
            valid_idx.append(i)
    return y_obs_list, np.array(y_tgt_list), m_list, valid_idx

def extract_eval_curves(y_full):
    y_obs_list, m_list = [], []
    for i in range(y_full.shape[0]):
        curve = y_full[i]
        non_nans = np.where(~np.isnan(curve))[0]
        if len(non_nans) == 0:
            M = 0; y_obs_list.append(np.array([]))
        else:
            M = non_nans[-1] + 1
            y_obs_list.append(curve[:M])
        m_list.append(M)
    return y_obs_list, m_list

y_train_obs, y_train_tgt, train_m, train_valid_idx = extract_train_curves(train_full)
y_eval_obs, eval_m = extract_eval_curves(eval_full)
print(f"Extracted {len(y_train_obs)} valid training curves (length >= 17).")
# Out:
# Extracted 40200 valid training curves (length >= 17).

# %% [markdown]
# ## Section 2: Preprocessing & NaN Handling

# %%
def clean_curve(curve, method='forward'):
    if len(curve) == 0: return curve
    if np.isnan(curve).any():
        if method == 'forward':
            df = pd.Series(curve).ffill().bfill()
            return df.to_numpy()
    return curve

y_train_clean = [clean_curve(c, CFG['preprocessing']['nan_handling']) for c in y_train_obs]
y_eval_clean = [clean_curve(c, CFG['preprocessing']['nan_handling']) for c in y_eval_obs]

# %% [markdown]
# ## Section 3: Parametric Curve Fitting

# %%
def pow2(x, a, c): return a * (x**(-c))

def fit_pow2_curve(y_curve, x_anchors, n_inits=1):
    if len(y_curve) < 3: return np.array([0.0, 0.0])
    best_params, best_mse = [0.0, 0.0], float('inf')
    for _ in range(n_inits):
        try:
            p0 = [np.random.uniform(0.01, 1.0), np.random.uniform(0.01, 1.0)]
            params, _ = curve_fit(pow2, x_anchors, y_curve, p0=p0, bounds=([0, 0], [np.inf, np.inf]), maxfev=2000)
            y_pred = pow2(x_anchors, *params)
            mse = mean_squared_error(y_curve, y_pred)
            if mse < best_mse:
                best_mse = mse; best_params = params
        except Exception: continue
    if best_mse == float('inf'): return np.array([0.0, 0.0])
    return np.array(best_params)

def extract_fit_features(y_cleaned_list, m_list):
    n_inits = CFG['fitting']['n_inits']
    n_jobs = CFG['fitting']['n_jobs']
    # Currently hardcoded to pow2 inside this function, can be expanded 
    params_list = Parallel(n_jobs=n_jobs)(
        delayed(fit_pow2_curve)(y_cleaned_list[i], x_anchors_all[:m_list[i]], n_inits)
        for i in range(len(y_cleaned_list))
    )
    return np.array(params_list)

print("Extracting fit features for train...")
train_fit_params = extract_fit_features(y_train_clean, train_m)
print("Extracting fit features for eval...")
eval_fit_params = extract_fit_features(y_eval_clean, eval_m)
# Out:
# Extracting fit features for train...
# Extracting fit features for eval...

# %% [markdown]
# ## Section 4: Feature Engineering

# %%
def build_features(m_list, fit_params):
    features = []
    m_array = np.array(m_list).reshape(-1, 1)
    features.append(m_array)
    if CFG['features']['use_params']:
        features.append(fit_params)
    return np.hstack(features)

X_train = build_features(train_m, train_fit_params)
X_eval = build_features(eval_m, eval_fit_params)
y_train_tgt = np.array(y_train_tgt)
print(f"X_train Feature Matrix shape: {X_train.shape}")
# Out:
# X_train Feature Matrix shape: (40200, 3)

# %% [markdown]
# ## Section 5: Meta-Model Training & Optimization

# %%
X_t, X_v, y_t, y_v = train_test_split(
    X_train, y_train_tgt, 
    test_size=CFG['data']['val_split'], 
    random_state=CFG['data']['random_seed']
)

model_type = CFG['model']['type']
tuning_method = CFG['tuning']['method']

if model_type == 'ridge':
    base_model = Pipeline([('scaler', StandardScaler()), ('model', Ridge())])
    param_grid = {'model__alpha': [0.01, 0.1, 1.0, 10.0, 100.0, 500.0]}
elif model_type == 'rf':
    base_model = Pipeline([('scaler', StandardScaler()), ('model', RandomForestRegressor(random_state=42))])
    param_grid = {'model__n_estimators': [50, 100], 'model__max_depth': [None, 10, 20]}
elif model_type == 'hgb':
    base_model = Pipeline([('scaler', StandardScaler()), ('model', HistGradientBoostingRegressor(random_state=CFG['data']['random_seed']))])
    param_grid = {'model__learning_rate': [0.05, 0.1, 0.2], 'model__max_iter': [100, 200], 'model__max_depth': [None, 5, 10]}
else:
    raise ValueError(f"Unknown model_type: {model_type}")

print(f"Setting up model pipeline: {model_type} with StandardScaler")

if tuning_method == 'grid':
    print(f"Running GridSearchCV with {CFG['tuning']['cv_folds']}-fold cross validation...")
    model = GridSearchCV(base_model, param_grid, cv=CFG['tuning']['cv_folds'], 
                         scoring='neg_mean_squared_error', n_jobs=CFG['tuning']['n_jobs'])
    model.fit(X_t, y_t)
    print(f"Best parameters found: {model.best_params_}")

elif tuning_method == 'halving':
    print(f"Running HalvingGridSearchCV with {CFG['tuning']['cv_folds']}-fold cross validation...")
    model = HalvingGridSearchCV(base_model, param_grid, cv=CFG['tuning']['cv_folds'], 
                                scoring='neg_mean_squared_error', n_jobs=CFG['tuning']['n_jobs'],
                                random_state=42, factor=3)
    model.fit(X_t, y_t)
    print(f"Best parameters found: {model.best_params_}")

else:
    print("No tuning requested. Running baseline fit...")
    model = base_model
    model.fit(X_t, y_t)
    
y_pred_t = model.predict(X_t)
y_pred_v = model.predict(X_v)
y_pred_eval = model.predict(X_eval)

print(f"Valid MSE: {mean_squared_error(y_v, y_pred_v):.5f}")
# Out:
# Setting up model pipeline: ridge with StandardScaler
# Running GridSearchCV with 3-fold cross validation...
# Best parameters found: {'model__alpha': 500.0}
# Valid MSE: 0.02816

# %% [markdown]
# ## Section 6: Uncertainty Estimation

# %%
residuals = y_v - y_pred_v
sigma = np.std(residuals)
print(f"Estimated sigma from validation residuals: {sigma:.5f}")

def construct_probability_bins(preds, sigma, n_bins=1000):
    bins = np.linspace(0, 1, n_bins)
    probs = []
    for p in preds:
        dist = norm.pdf(bins, loc=p, scale=sigma)
        dist = np.clip(dist, a_min=1e-10, a_max=None)
        dist = dist / np.sum(dist)
        probs.append(dist)
    return np.array(probs, dtype=np.float32)

val_probs = construct_probability_bins(y_pred_v, sigma)
eval_probs = construct_probability_bins(y_pred_eval, sigma)
# Out:
# Estimated sigma from validation residuals: 0.16782

# %% [markdown]
# ## Section 7: Local Evaluation

# %%
def calculate_median_nll(probs, true_y, n_bins=1000):
    bin_idx = np.clip(np.floor(true_y * n_bins).astype(int), 0, n_bins - 1)
    prob_true = probs[np.arange(len(probs)), bin_idx]
    nll = -np.log(prob_true)
    return np.median(nll)

median_nll = calculate_median_nll(val_probs, y_v)
print(f"Local Validation Median NLL: {median_nll:.4f}")
# Out:
# Local Validation Median NLL: 6.0951

# %% [markdown]
# ## Section 8: Kaggle Submission & Diagnostics

# %%
n_bins = eval_probs.shape[1]
df_sub = pd.DataFrame(eval_probs, columns=[f"bin_{i}" for i in range(n_bins)])
df_sub.insert(0, "id", np.arange(len(eval_probs)))

out_dir = CFG['submission']['out_dir']
os.makedirs(out_dir, exist_ok=True)

exp_name = CFG['experiment_name']
out_path = os.path.join(out_dir, f"sub_{exp_name}.csv")

df_sub.to_csv(out_path, index=False)
print(f"Submission saved to {out_path}.")

log_path = 'experiment_logs.csv'

log_data = {
    'timestamp': pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    'experiment_name': exp_name,
    'model_type': CFG['model']['type'],
    'tuning_method': CFG['tuning']['method'],
    'best_params': str(getattr(model, 'best_params_', 'None')),
    'local_median_nll': median_nll
}

df_log = pd.DataFrame([log_data])
if os.path.exists(log_path):
    df_log.to_csv(log_path, mode='a', header=False, index=False)
else:
    df_log.to_csv(log_path, index=False)
    
print(f"Experiment logged to {log_path}.")

bin_idx = np.clip(np.floor(y_v * 1000).astype(int), 0, 999)
prob_true = val_probs[np.arange(len(val_probs)), bin_idx]
nlls = -np.log(prob_true)

plt.figure(figsize=(8,4))
sns.histplot(nlls, bins=50, kde=True)
plt.title(f"Validation NLL: {median_nll:.4f} | Exp: {exp_name}")
plt.xlabel("NLL")
plt.show()
# Out:
# Submission saved to submissions/sub_baseline_ridge_scaled_v1.csv.
# Experiment logged to experiment_logs.csv.
